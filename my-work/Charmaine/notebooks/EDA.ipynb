# %%
# 1)Import libraries
# Core BigQuery client
from google.cloud import bigquery

# Optional but common companions
import pandas as pd
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779962701.205242    2247 instrument.cc:563] Metric with name 'grpc.resource_quota.calls_dropped' registered more than once. Ignoring later registration.
# E0000 00:00:1779962701.206077    2247 instrument.cc:563] Metric with name 'grpc.resource_quota.calls_rejected' registered more than once. Ignoring later registration.
# E0000 00:00:1779962701.206088    2247 instrument.cc:563] Metric with name 'grpc.resource_quota.connections_dropped' registered more than once. Ignoring later registration.
# E0000 00:00:1779962701.206093    2247 instrument.cc:563] Metric with name 'grpc.resource_quota.instantaneous_memory_pressure' registered more than once. Ignoring later registration.
# E0000 00:00:1779962701.206097    2247 instrument.cc:563] Metric with name 'grpc.resource_quota.memory_pressure_control_value' registered more than once. Ignoring later registration.

# %%
# 2) Authenticate
# Option 1 — Service account key file (most common in notebooks)
from google.oauth2 import service_account

credentials = service_account.Credentials.from_service_account_file(
    '/home/szemainwong/mainitexp1-856bc2c1e42f.json'
)
client = bigquery.Client(credentials=credentials, project='mainitexp1')

# %%
# List all tables in a dataset
dataset_ref = client.dataset("Brazil_ecommerce", project="mainitexp1")
tables = list(client.list_tables(dataset_ref))

for table in tables:
    print(table.table_id)   # prints the exact table name to use
# Out:
# olist_customers_dataset
# olist_geolocation_dataset
# olist_order_items_dataset
# olist_order_payments_dataset
# olist_order_reviews_dataset
# olist_orders_dataset
# olist_products_dataset
# olist_sellers_dataset
# product_category_name_translation

# %%
#!!DO NOT RUN THIS CELL!!
# !pip install db-dtypes==1.4.3
# Out:
# Collecting db-dtypes==1.4.3
#   Downloading db_dtypes-1.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.24.0 in /home/szemainwong/miniconda3/envs/elt/lib/python3.11/site-packages (from db-dtypes==1.4.3) (2.4.4)
# Requirement already satisfied: packaging>=24.2.0 in /home/szemainwong/miniconda3/envs/elt/lib/python3.11/site-packages (from db-dtypes==1.4.3) (25.0)
# Requirement already satisfied: pandas>=1.5.3 in /home/szemainwong/miniconda3/envs/elt/lib/python3.11/site-packages (from db-dtypes==1.4.3) (2.3.3)
# Requirement already satisfied: pyarrow>=13.0.0 in /home/szemainwong/miniconda3/envs/elt/lib/python3.11/site-packages (from db-dtypes==1.4.3) (24.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/szemainwong/miniconda3/envs/elt/lib/python3.11/site-packages (from pandas>=1.5.3->db-dtypes==1.4.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/szemainwong/miniconda3/envs/elt/lib/python3.11/site-packages (from pandas>=1.5.3->db-dtypes==1.4.3) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/szemainwong/miniconda3/envs/elt/lib/python3.11/site-packages (from pandas>=1.5.3->db-dtypes==1.4.3) (2026.2)
# Requirement already satisfied: six>=1.5 in /home/szemainwong/miniconda3/envs/elt/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->db-dtypes==1.4.3) (1.17.0)
# Downloading db_dtypes-1.4.3-py3-none-any.whl (18 kB)
# Installing collected packages: db-dtypes
#   Attempting uninstall: db-dtypes
#     Found existing installation: db-dtypes 1.6.0
#     Uninstalling db-dtypes-1.6.0:
#       Successfully uninstalled db-dtypes-1.6.0
# Successfully installed db-dtypes-1.4.3

# %%
import db_dtypes

# %%
# 3) Read the tables
# --- Read entire table directly ---
table_ref = client.get_table("mainitexp1.Brazil_ecommerce.olist_customers_dataset") #get_table("your_project.your_dataset.your_table")
df = client.list_rows(table_ref).to_dataframe()
df.head()
# Out:
# /home/szemainwong/miniconda3/envs/elt1/lib/python3.11/site-packages/google/cloud/bigquery/table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(
#                         customer_id                customer_unique_id  \
# 0  2201362e68992f654942dc0067c1b716  f7d7fc0a59ef4363fdce6e3aa069d498
# 1  31dbc13addc753e210692eacaea065e4  5dbba6c01268a8ad43f79157bf4454a0
# 2  dad907e170748a35ef4e92238b7308f3  36b1c0516f123351ffa87430416dcae5
# 3  888d2ebe1af2a8c93c75dae5dfc23719  721d1092e1a6460c67e6a0e691d899a3
# 4  8a0108267d9258a0ec9f74381bc9b0de  7a2dc4682890550ebe3b8befcea3d55c
#
#    customer_zip_code_prefix customer_city customer_state
# 0                     69900    rio branco             AC
# 1                     69900    rio branco             AC
# 2                     69900    rio branco             AC
# 3                     69900    rio branco             AC
# 4                     69900    rio branco             AC
